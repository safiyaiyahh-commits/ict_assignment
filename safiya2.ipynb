# %%
1.
FizzBuzz
FizzBuzz: For a given range of numbers (e.g., 1 to 100), print "Fizz" if the number is divisible by 3, "Buzz" if it's divisible by 5, and "FizzBuzz" if it's divisible by both. Otherwise, print the number itself

# %%
for i in range(1,100):
    if  i%3==0:
        print('fizz')
    elif i%5==0:
        print('buzz')
    elif i%3==0 and i%5==0:
        print('fizzbuzz')
    else:
        print(i)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizz
# 46
# 47
# fizz
# 49
# buzz
# fizz
# 52
# 53
# fizz
# buzz
# 56
# fizz
# 58
# 59
# fizz
# 61
# 62
# fizz
# 64
# buzz
# fizz
# 67
# 68
# fizz
# buzz
# 71
# fizz
# 73
# 74
# fizz
# 76
# 77
# fizz
# 79
# buzz
# fizz
# 82
# 83
# fizz
# buzz
# 86
# fizz
# 88
# 89
# fizz
# 91
# 92
# fizz
# 94
# buzz
# fizz
# 97
# 98
# fizz

# %%
2.
Electricity Bill calculator
Create a bill calculator where the user enters the number of units consumed. ₹5 per unit for the first 100 units ₹7 per unit for the next 100 units (from 101 to 200) ₹10 per unit for any units above 200 Calculate and display the total electricity bill.
Sample Input:
Enter units consumed: 245
Sample Output:
Total Bill Amount: ₹1650

# %%
bill=0
u=int(input('enter consumer number'))
if u<=100:
    print('total bill=',u*5)
elif 100<u<=200:
    print('total bill',(100*5)+(100*7))
else:
    print('total bill',((100*5)+(100*7)+(u-200)*10))
# Out:
# enter consumer number245
# total bill 1650

# %% [raw]
# 3. Display a pattern for a simple progress indicator.
# *
# **
# ***
# ****
# *****

# %%
a=int(input('enter the number'))
for i in range(1,a+1):
    ind="*"*i
    print(ind)
# Out:
# enter the number5
# *
# **
# ***
# ****
# *****

# %% [raw]
# 4. Palindrome
# Develop a Python program that checks whether a given word or phrase is a
# palindrome.
#  Sample input
#  Enter num or string to be checked = 121
#  Sample Output
#  Given num/string is Palindrome

# %%
n=input('enter number')
if n.lower()==n[::-1].lower():
    print('palindrome')
else:
    print(' not palindrome')
# Out:
# enter number121
# palindrome
